# %%
from datasets import dataGen, df_tabular_data
import matplotlib.pyplot as plt
import matplotlib as mpl
from methods import *
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
train_path = '../privateDemographics/data/synthetic_moon_(100,30,300)_circles_(200,30,300)_factor_0.5_blobs_(1000,300,300)_noise_(0.1,0.1,0.1)_seed_123/train.csv'
val_path = '../privateDemographics/data/synthetic_moon_(100,30,300)_circles_(200,30,300)_factor_0.5_blobs_(1000,300,300)_noise_(0.1,0.1,0.1)_seed_123/val.csv'
test_path = '../privateDemographics/data/synthetic_moon_(100,30,300)_circles_(200,30,300)_factor_0.5_blobs_(1000,300,300)_noise_(0.1,0.1,0.1)_seed_123/test.csv'

# %%
start_model_path = '../privateDemographics/models/synthetic/erm_num_epoch_100_batch_size_128_lr_0.001_subsample_0_weight_decay_0.001_best.model'
pred_dict_path = '../privateDemographics/results/synthetic/pred_dict.json'

# %%
folder_name = '../privateDemographics/results/%s' % 'civilcomments'

# %%
for min_samples in [5, 10, 20, 30, 40, 50, 60, 100]:
    for eps in np.linspace(0.1, 0.7, 13):
        pred_groups(
            dataset_name = 'synthetic',
            batch_size = 128,
            seed = 123,
            device = 'cpu',
            y = 1,
            min_samples = 60,
            eps = 0.1,
            start_model_path = start_model_path,
            log_wandb = 0,
        )
# Out:
# Loaded all the gradient information into folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/results/synthetic...
# Best avg IOU [0.0, 0.9478260869565217, 0.9984615384615385]
# {0: 'all others', 1: -1, 2: 0}
# Best avg IOU 2 [0.0, 0.6526946107784432, 0.9788838612368024]
# {0: 'all others', 1: -1, 2: 0}
# Weighted avg 0.6127072093598888
# Loaded all the gradient information into folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/results/synthetic...
# Best avg IOU [0.0, 0.9478260869565217, 0.9984615384615385]
# {0: 'all others', 1: -1, 2: 0}
# Best avg IOU 2 [0.0, 0.6526946107784432, 0.9788838612368024]
# {0: 'all others', 1: -1, 2: 0}
# Weighted avg 0.6127072093598888
# Loaded all the gradient information into folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/results/synthetic...
# Best avg IOU [0.0, 0.9478260869565217, 0.9984615384615385]
# {0: 'all others', 1: -1, 2: 0}
# ...

# %%
for min_samples in [5, 10, 20, 30, 40, 50, 60, 100]:
    for eps in np.linspace(0.1, 0.7, 13):
        pred_groups(
            dataset_name = 'waterbirds',
            batch_size = 128,
            seed = 123,
            device = 'cpu',
            y = 1,
            min_samples = 60,
            eps = 0.1,
            start_model_path = start_model_path,
            log_wandb = 0,
        )
# Out:
# Representations are loaded from folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/data/waterbirds_resnet50_representation!
# CUDA device not available. Skip...
# Loaded all the gradient information into folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/results/waterbirds...
# Best avg IOU [0.6772486772486772, 0.8100840336134454, 0.0]
# {0: -1, 1: 0, 2: 'all others'}
# Best avg IOU 2 [0.3615819209039548, 0.9404878048780487, 0.0]
# {0: -1, 1: 0, 2: 'all others'}
# Weighted avg 0.44011871012905845
# Representations are loaded from folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/data/waterbirds_resnet50_representation!
# CUDA device not available. Skip...
# Loaded all the gradient information into folder /Users/zengyuchen/research/IBM/dccstore/storage/privateDemographics/results/waterbirds...
# Best avg IOU [0.6772486772486772, 0.8100840336134454, 0.0]
# {0: -1, 1: 0, 2: 'all others'}
# ...

# %%
pred_groups(
    dataset_name = 'synthetic',
    batch_size = 128,
    seed = 123,
    device = 'cpu',
    y = 1,
    min_samples = 60,
    eps = 0.1,
    start_model_path = start_model_path,
    log_wandb = 0,
)
# Out:
# Loaded all the gradient information into folder ../privateDemographics/results/synthetic...
# Best avg IOU [0.0, 0.9478260869565217, 0.9984615384615385]
# {0: 'all others', 1: -1, 2: 0}
# Best avg IOU 2 [0.0, 0.6526946107784432, 0.9788838612368024]
# {0: 'all others', 1: -1, 2: 0}
# Weighted avg 0.6127072093598888

# %%
run_exp(
    method = 'grass', 
    batch_size = 128, 
    lr = 0,
    lr_q = 0,
    num_epoch = 1,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cpu',
    dataset_name = 'synthetic',
    log_wandb = 0,
    weight_decay = .001,
    start_model_path = start_model_path,
    load_pred_dict = False,
    clustering_path_use = False,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 run_exp(
#       2     method = 'grass',
#       3     batch_size = 128,
#       4     lr = 0,
#       5     lr_q = 0,
#       6     num_epoch = 1,
#       7     seed = 123,
#       8     target_var = 'y',
#       9     domain = 'a',
#      10     device = 'cpu',
#      11     dataset_name = 'synthetic',
#      12     log_wandb = 0,
#      13     weight_decay = .001,
#      14     start_model_path = start_model_path,
#      15     load_pred_dict = False,
#      16     clustering_path_use = False,
#      17 )
#
# ...

# %%
run_exp(
    method = 'grass', 
    batch_size = 128, 
    lr = 0,
    lr_q = 0,
    num_epoch = 1,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cpu',
    dataset_name = 'synthetic',
    log_wandb = 0,
    weight_decay = .001,
    start_model_path = start_model_path,
    load_pred_dict = False,
    clustering_path_use = True,
)
# Out:
# Computing the gradients...
# Epoch: 2: 100%|██████████| 11/11 [00:00<00:00, 93.74it/s]
# Saving all the gradient information into folder ../privateDemographics/results/synthetic...
# All the gradient information are saved in folder ../privateDemographics/results/synthetic!
# Estimated domains are saved in ../privateDemographics/results/synthetic/pred_dict.json
# Adjusted Rand Score of Group Prediction: 0.8621!
# =============== Training ===============
# Epoch: 1: 100%|██████████| 11/11 [00:00<00:00, 271.74it/s]
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 80.00% | 97.00% |100.00% | 84.00% | 94.00% |100.00% |
# |      loss      |   0.38 |   0.19 |   0.00 |   0.33 |   0.22 |   0.00 |
# ------------------------------------------------------------------------
# ...

# %%
run_exp(
    method = 'grass', 
    batch_size = 128, 
    lr = 0,
    lr_q = 0,
    num_epoch = 1,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cpu',
    dataset_name = 'synthetic',
    log_wandb = 0,
    weight_decay = .001,
    start_model_path = start_model_path,
    load_pred_dict = False,
)
# Out:
# Computing the gradients...
# Epoch: 2: 100%|██████████| 11/11 [00:00<00:00, 426.87it/s]
# Saving all the gradient information into folder ../privateDemographics/results/synthetic...
# All the gradient information are saved in folder ../privateDemographics/results/synthetic!
# Estimated domains are saved in ../privateDemographics/results/synthetic/pred_dict.json
# Adjusted Rand Score of Group Prediction: 0.6968!
# =============== Training ===============
# Epoch: 1: 100%|██████████| 11/11 [00:00<00:00, 310.22it/s]
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 80.00% | 94.00% |100.00% | 86.00% | 97.00% |100.00% |
# |      loss      |   0.40 |   0.21 |   0.00 |   0.33 |   0.21 |   0.00 |
# ------------------------------------------------------------------------
# ...

# %%
wandb.finish()

# %%
run_exp(
    method = 'grass', 
    model = 'mlp',
    train_path = train_path,
    val_path = val_path,
    test_path = test_path,
    batch_size = 128, 
    lr = .001,
    lr_q = .001,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cpu',
    dataset_name = 'synthetic',
    train_supp_frac = 0, 
    log_wandb = 0,
    weight_decay = .001,
    start_model_path = start_model_path,
    pred_dict_path = pred_dict_path,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 11/11 [00:00<00:00, 360.05it/s]
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 64.00% | 71.00% |100.00% | 92.00% | 99.00% |100.00% |
# |      loss      |   0.70 |   0.35 |   0.00 |   0.27 |   0.10 |   0.00 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.0728
# | Worst-case Accuracy: 64.00%
# | Average Accuracy: 96.00%
# | Reweighted Accuracy: 96.00%
# ##############################
# # Predicted Group Statistics #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# ...

# %%
run_exp(
    method = 'robust_dro', 
    model = 'mlp',
    train_path = train_path,
    val_path = val_path,
    test_path = test_path,
    batch_size = 128, 
    lr = .001,
    num_epoch = 100,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cpu',
    dataset_name = 'synthetic',
    train_supp_frac = 0, 
    log_wandb = 0,
    weight_decay = .01,
    lr_q = .001,
    start_model_path = start_model_path,
    pred_dict_path = None,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 11/11 [00:00<00:00, 83.97it/s]
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    |  4.00% | 41.00% |99.60% | 38.00% | 87.00% |100.00% |
# |      loss      |   0.77 |   0.71 |   0.50 |   0.70 |   0.68 |   0.14 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.4081
# | Worst-case Accuracy: 4.00%
# | Average Accuracy: 88.23%
# | Reweighted Accuracy: 88.23%
# =============== Validation ===============
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# ...

# %%
run_exp(
    method = 'erm', 
    model = 'mlp',
    train_path = train_path,
    val_path = val_path,
    test_path = test_path,
    batch_size = 128, 
    lr = 1e-3,
    num_epoch = 100,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cuda:0',
    dataset_name = 'synthetic',
    train_supp_frac = 0, 
    log_wandb = 0,
    weight_decay = .0001,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 17/17 [00:00<00:00, 454.20it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 40.00% | 40.20% |100.00% | 22.00% | 62.80% |100.00% |
# |      loss      |   0.80 |   0.78 |   0.36 |   0.76 |   0.64 |   0.06 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.4740
# | Worst-case Accuracy: 22.00%
# | Average Accuracy: 73.62%
# | Reweighted Accuracy: 73.62%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 33.33% | 43.33% |100.00% | 26.67% | 64.00% |100.00% |
# |      loss      |   0.81 |   0.80 |   0.35 |   0.75 |   0.64 |   0.06 |
# ...

# %%
run_exp(
    method = 'grass', 
    train_path = train_path,
    val_path = val_path,
    test_path = test_path,
    batch_size = 128, 
    lr = 1e-4,
    num_epoch = 1,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cuda:0',
    dataset_name = 'synthetic',
    log_wandb = 0,
    weight_decay = .0001,
    start_model_path = '../privateDemographics/models/synthetic/erm_num_epoch_100_batch_size_128_lr_0.001_subsample_0_weight_decay_0.01_best.model',
    load_pred_dict = False,
)
# Out:
# Epoch: 2: 100%|██████████| 11/11 [00:00<00:00, 51.23it/s]
# Eps 0.1 Min samples 5
# Cluster counts (array([-1,  0,  1,  2,  3,  4,  5]), array([ 27, 707,  36,  22,  28,   5,   5]))
# ARS 0.6938885998914782 NMI 0.4848173584107445
# Best avg IOU [0.09230769230769231, 0.591304347826087, 0.9984615384615385]
# {0: -1, 1: 'all others', 2: 0}
# Best avg IOU 2 [0.2916666666666667, 0.7407407407407407, 0.917963224893918]
# {0: 'all others', 1: -1, 2: 0}
#
#
# Eps 0.1 Min samples 10
# Cluster counts (array([-1,  0,  1,  2,  3]), array([ 44, 706,  32,  20,  28]))
# ARS 0.698427784650881 NMI 0.5046745005824662
# Best avg IOU [0.16923076923076924, 0.4956521739130435, 0.9984615384615385]
# {0: -1, 1: 'all others', 2: 0}
# Best avg IOU 2 [0.2875, 0.7272727272727273, 0.9192634560906515]
# {0: 'all others', 1: -1, 2: 0}
#
#
# Eps 0.1 Min samples 20
# Cluster counts (array([-1,  0,  1]), array([101, 705,  24]))
# ARS 0.6998550357782024 NMI 0.49800989602046575
# ...

# %%
run_exp(
    method = 'grass', 
    train_path = train_path,
    val_path = val_path,
    test_path = test_path,
    batch_size = 128, 
    lr = 1e-4,
    num_epoch = 1,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    device = 'cuda:0',
    dataset_name = 'synthetic',
    log_wandb = 0,
    weight_decay = .0001,
    start_model_path = '../privateDemographics/models/synthetic/erm_num_epoch_100_batch_size_128_lr_0.001_subsample_0_weight_decay_0.01_best.model',
    load_pred_dict = True,
)
# Out:
# Adjusted Rand Score of Group Prediction: 0.8507!
# =============== Training ===============
# Epoch: 1: 100%|██████████| 11/11 [00:00<00:00, 208.47it/s]
# ##############################
# #    True Group Statistics   #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 74.00% | 84.00% |100.00% | 88.00% | 99.00% |100.00% |
# |      loss      |   0.46 |   0.28 |   0.00 |   0.36 |   0.17 |   0.00 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.0659
# | Worst-case Accuracy: 74.00%
# | Average Accuracy: 97.23%
# | Reweighted Accuracy: 97.23%
# ##############################
# # Predicted Group Statistics #
# ##############################
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# ...

# %%
run_exp(
    method = 'gong_et_al', 
    model = 'mlp',
    train_path = train_csv,
    m = 5,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    inner_lr = .002,
    outer_lr = .5,
    num_epoch = 100,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:0',
    optimizer = 'sgd',
    dataset_name = 'synthetic',
    train_supp_frac = 0, 
    log_wandb = 0,
)
# Out:
# | ======= Warm up starts ======= |
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 184.36it/s]
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% |  0.00% |  4.00% | 26.00% |  0.00% |
# |  avg-case acc  | 90.33% | 90.75% | 89.75% | 91.75% | 50.00% |
# |  fairness loss |   1.76 |   3.68 |   1.55 |   1.62 |   2.14 |
# ---------------------------------------------------------------
# | Accuracy Loss: 0.1634
# | Diversity Loss: 1.7072
# | Worst-case Accuracy: 26.00%
# | Average Accuracy: 91.75%
# | Reweighted Accuracy: 91.75%
# =============== Validation ===============
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% |  0.00% |  6.67% | 26.67% |  0.00% |
# |  avg-case acc  | 90.28% | 90.56% | 90.00% | 91.94% | 50.00% |
# ...

# %%
run_exp(
    method = 'gong_et_al', 
    model = 'mlp',
    train_path = train_csv,
    m = 5,
    val_path = val_csv,
    test_path = test_csv,
    data_type = 'tabular',
    batch_size = 128, 
    inner_lr = .001,
    outer_lr = .5,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:1',
    optimizer = 'sgd',
    train_supp_frac = 0, 
    log_wandb = 0,
    bilevel_mode = 'max',
)
# Out:
# | ======= Warm up starts ======= |
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 194.56it/s]
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% | 12.00% | 10.00% |  0.00% | 22.00% |
# |  avg-case acc  | 90.08% | 89.83% | 89.67% | 89.67% | 89.67% |
# |  fairness loss |   1.04 |   0.95 |   1.03 |   1.13 |   0.97 |
# ---------------------------------------------------------------
# | Accuracy Loss: 0.1560
# | Diversity Loss: 1.8192
# | Worst-case Accuracy: 22.00%
# | Average Accuracy: 89.67%
# =============== Validation ===============
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% | 20.00% | 13.33% |  0.00% | 20.00% |
# |  avg-case acc  | 90.00% | 90.56% | 90.00% | 89.44% | 89.72% |
# |  fairness loss |   1.03 |   0.95 |   1.03 |   1.12 |   0.98 |
# ...

# %%
run_exp(
    method = 'fair_diverse', 
    model = 'mlp',
    train_path = train_csv,
    m = 5,
    val_path = val_csv,
    test_path = test_csv,
    data_type = 'tabular',
    batch_size = 128, 
    inner_lr = .002,
    outer_lr = 1,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:1',
    optimizer = 'sgd',
    train_supp_frac = 0, 
    log_wandb = 0,
)
# Out:
# | ======= Warm up starts ======= |
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 193.19it/s]
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% | 12.00% | 10.00% |  0.00% | 22.00% |
# |  avg-case acc  | 90.08% | 89.83% | 89.67% | 89.67% | 89.67% |
# |  fairness loss |   1.04 |   0.95 |   1.03 |   1.13 |   0.97 |
# ---------------------------------------------------------------
# | Accuracy Loss: 0.1560
# | Diversity Loss: 1.8192
# | Worst-case Accuracy: 22.00%
# | Average Accuracy: 89.67%
# =============== Validation ===============
# ---------------------------------------------------------------
# |      metric    | model 0| model 1| model 2| model 3| model 4|
# | wrost-case acc |  0.00% | 20.00% | 13.33% |  0.00% | 20.00% |
# |  avg-case acc  | 90.00% | 90.56% | 90.00% | 89.44% | 89.72% |
# |  fairness loss |   1.03 |   0.95 |   1.03 |   1.12 |   0.98 |
# ...

# %%
run_exp(
    method = 'fair_dro_and_diverse',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 32, 
    inner_lr = .002,
    outer_lr = 1,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    diverse_lambda = 0,
    device = 'cuda:1',
    train_supp_frac = 0, 
    log_wandb = 0,
)
# Out:
# | ======= Warm up starts ======= |
# Epoch: 1: 100%|██████████| 38/38 [00:00<00:00, 741.32it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 62.00% | 48.00% |100.00% |  0.00% | 54.00% |100.00% |
# |      loss      |   0.65 |   0.75 |   0.04 |   1.02 |   0.69 |   0.01 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.1518
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 0.00%
# | Average Accuracy: 90.17%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 60.00% | 46.67% |100.00% |  0.00% | 53.33% |100.00% |
# |      loss      |   0.66 |   0.77 |   0.03 |   1.01 |   0.69 |   0.01 |
# ...

# %%
run_exp(
    method = 'fair_robust_dro_and_diverse',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    lr_w = .001,
    lr_q = .0005,
    outer_lr = 1,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    diverse_lambda = 0,
    device = 'cuda:1',
    train_supp_frac = 0, 
    log_wandb = 0,
)
# Out:
# | ======= Warm up starts ======= |
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 578.84it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 62.00% | 48.00% |100.00% |  0.00% | 52.00% |100.00% |
# |      loss      |   0.65 |   0.75 |   0.04 |   1.04 |   0.70 |   0.01 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.1516
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 0.00%
# | Average Accuracy: 90.08%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 60.00% | 46.67% |100.00% |  0.00% | 53.33% |100.00% |
# |      loss      |   0.65 |   0.76 |   0.03 |   1.03 |   0.70 |   0.01 |
# ...

# %%
run_exp(
    method = 'dro',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    lr = .002,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:1',
    optimizer = 'adam',
    log_wandb = 0,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 183.29it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 74.00% | 64.00% |100.00% | 86.00% | 26.00% | 95.40% |
# |      loss      |   0.69 |   0.69 |   0.60 |   0.69 |   0.70 |   0.68 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.6504
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 26.00%
# | Average Accuracy: 91.83%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 66.67% | 60.00% |100.00% | 86.67% | 20.00% | 94.67% |
# |      loss      |   0.69 |   0.69 |   0.60 |   0.69 |   0.70 |   0.68 |
# ...

# %%
run_exp(
    method = 'robust_dro',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    lr_q = .001,
    lr_w = .01,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:1',
    optimizer = 'adam',
    log_wandb = 0,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 173.25it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 66.00% | 38.00% |100.00% | 98.00% | 82.00% |100.00% |
# |      loss      |   0.66 |   0.76 |   0.01 |   0.39 |   0.57 |   0.00 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.1064
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 38.00%
# | Average Accuracy: 95.17%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 60.00% | 26.67% |100.00% | 93.33% | 86.67% |100.00% |
# |      loss      |   0.67 |   0.79 |   0.01 |   0.40 |   0.57 |   0.00 |
# ...

# %%
run_exp(
    method = 'robust_dro',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    lr_q = .001,
    lr_w = .01,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:1',
    optimizer = 'adam',
    log_wandb = 0,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 31.10it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 66.00% | 38.00% |100.00% | 98.00% | 82.00% |100.00% |
# |      loss      |   0.66 |   0.76 |   0.01 |   0.39 |   0.57 |   0.00 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.1064
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 38.00%
# | Average Accuracy: 95.17%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 60.00% | 26.67% |100.00% | 93.33% | 86.67% |100.00% |
# |      loss      |   0.67 |   0.79 |   0.01 |   0.40 |   0.57 |   0.00 |
# ...

# %%
run_exp(
    method = 'irm',
    model = 'mlp',
    train_path = train_csv,
    m = 1,
    val_path = val_csv,
    test_path = test_csv,
    batch_size = 128, 
    lr_q = .001,
    lr_w = .01,
    num_epoch = 50,
    seed = 123,
    target_var = 'y',
    domain = 'a',
    ord = 'fro',
    s = 1,
    device = 'cuda:0',
    optimizer = 'adam',
    log_wandb = 0,
)
# Out:
# =============== Training ===============
# Epoch: 1: 100%|██████████| 10/10 [00:00<00:00, 33.49it/s]
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 96.00% | 62.00% |100.00% |  0.00% |  6.00% |100.00% |
# |      loss      |   0.66 |   0.68 |   0.45 |   0.76 |   0.71 |   0.34 |
# ------------------------------------------------------------------------
# | Accuracy Loss: 0.4488
# | Diversity Loss: 0.0000
# | Worst-case Accuracy: 0.00%
# | Average Accuracy: 90.17%
# | Reweighted Accuracy: 90.17%
# =============== Validation ===============
# ------------------------------------------------------------------------
# |      metric    | group 0| group 1| group 2| group 3| group 4| group 5|
# |    accuracy    | 86.67% | 66.67% |100.00% |  0.00% |  0.00% |100.00% |
# |      loss      |   0.66 |   0.68 |   0.45 |   0.76 |   0.71 |   0.34 |
# ...
